# %%
import pandas as pd

fn = "/u/scratch/s/schhina/AllPredictions.AvgHiC.ABC0.015.minus150.ForABCPaperV3.txt"

# %%
df = pd.read_csv(fn, sep='\t', header=0)

# %%
df.head()
# Out:
#     chr   start     end                         name     class  activity_base  \
# 0  chr1  710010  710210     genic|chr1:709860-710360     genic       0.420794
# 1  chr1  710036  710236     genic|chr1:709886-710386     genic       0.373477
# 2  chr1  710526  710956     genic|chr1:710376-711106     genic       0.776180
# 3  chr1  713731  714569  promoter|chr1:713581-714719  promoter       7.879375
# 4  chr1  713743  714641  promoter|chr1:713593-714791  promoter      12.744314
#
#      TargetGene  TargetGeneTSS  TargetGeneExpression  \
# 0  LOC100288069         714068                   NaN
# 1  LOC100288069         714068                   NaN
# 2  LOC100288069         714068                   NaN
# 3  LOC100288069         714068                   NaN
# 4  LOC100288069         714068                   NaN
#
#    TargetGenePromoterActivityQuantile  ...  powerlaw_contact  \
# 0                            0.815301  ...          0.125372
# ...

# %%
# True in this array means we want to keep the respective column
# In our case, we only want start, end and targetGene
cols = [ True, True, True, False, False, False, True, False, False,
       False, False, False, False, False, False, False, False, False,
       False, False, False, False, False, False]

# %%
temp_df = df.loc[:, cols]

# %%
temp_df.head()
# Out:
#     chr   start     end    TargetGene
# 0  chr1  710010  710210  LOC100288069
# 1  chr1  710036  710236  LOC100288069
# 2  chr1  710526  710956  LOC100288069
# 3  chr1  713731  714569  LOC100288069
# 4  chr1  713743  714641  LOC100288069

# %%
temp_df.shape
# Out:
# (7717392, 4)

# %%
# Add peak_id field which is a concatenation of chr, start and end
temp_df.loc[:, 'peak_id'] = temp_df['chr'] + '_' + temp_df['start'].astype(str) + '_' + temp_df['end'].astype(str)
# Out:
# /u/local/apps/anaconda3/2020.11/lib/python3.8/site-packages/pandas/core/indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
# Remove start, end and chr fields
temp_df = temp_df.drop(columns=['chr', 'start', 'end'])

# %%
# Rename TargetGene to gene_short_name
temp_df.rename(columns={'TargetGene': 'gene_short_name'}, inplace=True)

# %%
output_file = "/u/scratch/s/schhina/abc_peaks.csv"
temp_df.to_csv(output_file)
